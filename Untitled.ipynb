# %%
import matplotlib.pyplot as plt
import numpy as np

with open('D:/Thesis/LASD/measurements/zsysdf.ascii', 'r') as file:
    header = file.readline().strip().split()

    z = []

    
    for line in file:
        values = line.strip().split()

        try:
           z.append(float(values[header.index('z')]))

        except ValueError:
            continue

#making numpy arrays
z = np.array(z)

# %%
print(z)
# Out:
# [ 1.67440000e-01  1.75140000e-01  1.31630000e-01  1.26950000e-01
#   2.19020000e-01  9.12300000e-02  1.73500000e-01  1.23160000e-01
#   9.42600000e-02  1.81670000e-01  1.49140000e-01  7.57900000e-02
#   1.64887000e-01  6.10870000e-02  9.84000000e-02  1.36890000e-01
#   2.06000000e-02  1.26500000e-01  2.62236000e-01  2.41400000e-01
#   2.52645000e-01  1.94396000e-01  2.39420000e-01  2.63403000e-01
#   4.41870000e-02  3.01210000e-01  3.85930000e-02  6.54090000e-02
#   2.78430000e-02  6.22560000e-02  3.55700000e-01  2.93700000e-01
#   2.99300000e-01  3.68940000e-01  3.32200000e-01  4.31700000e-01
#   3.62900000e-01  6.35850000e-02  1.41000000e-01  2.08300000e-01
#   2.67100000e-01  8.22000000e-02  3.43100000e-01  4.42000000e-02
#   2.39800000e-01  2.63700000e-01  2.03400000e-01  2.38800000e-01
#   1.94600000e-01  2.68400000e-01  3.23700000e-01  3.20500000e-02
#   9.42000000e-02  4.26300000e-02  3.25000000e-02  3.27000000e-02
# ...
