# %%
import numpy as np
import matplotlib.pyplot as plt

def intrinsic_lya_lineshape(velocity, delta_v, sigma_alpha):
    """
    Model the Lyα line shape as a Gaussian.

    Parameters:
        velocity (numpy.ndarray): Array of velocity values (in km/s).
        delta_v (float): Velocity offset from the systemic redshift of the galaxy (in km/s).
        sigma_alpha (float): Velocity dispersion due to ISM scattering and thermal broadening (in km/s).

    Returns:
        numpy.ndarray: Intrinsic Lyα line shape values.
    """
    # Gaussian profile formula
    lineshape = (1 / (np.sqrt(2 * np.pi) * sigma_alpha)) * np.exp(-0.5 * ((velocity - delta_v) / sigma_alpha)**2)
    return lineshape

# Example usage
if __name__ == "__main__":
    # Define parameters
    delta_v = 200  # Velocity offset (km/s)
    sigma_alpha = 50  # Velocity dispersion (km/s)

    # Generate velocity array (km/s)
    velocity = np.linspace(-500, 500, 1000)

    # Compute the Lyα line shape
    lineshape = intrinsic_lya_lineshape(velocity, delta_v, sigma_alpha)

    # Plot the result
    plt.figure(figsize=(8, 6))
    plt.plot(velocity, lineshape, label=f"∆v={delta_v} km/s, σα={sigma_alpha} km/s")
    plt.title("Intrinsic Lyα Line Shape")
    plt.xlabel("Velocity (km/s)")
    plt.ylabel("Intensity")
    plt.legend()
    plt.grid()
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def intrinsic_lya_lineshape(velocity, delta_v, sigma_alpha):
    """
    Model the Lyα line shape as a Gaussian.

    Parameters:
        velocity (numpy.ndarray): Array of velocity values (in km/s).
        delta_v (float): Velocity offset from the systemic redshift of the galaxy (in km/s).
        sigma_alpha (float): Velocity dispersion due to ISM scattering and thermal broadening (in km/s).

    Returns:
        numpy.ndarray: Intrinsic Lyα line shape values.
    """
    # Gaussian profile formula
    lineshape = (1 / (np.sqrt(2 * np.pi) * sigma_alpha)) * np.exp(-0.5 * ((velocity - delta_v) / sigma_alpha)**2)
    return lineshape

def double_gaussian_lya_lineshape(velocity, v_separation, asymmetry, sigma_alpha):
    """
    Model the Lyα line shape as two Gaussians with a specified separation and asymmetry.

    Parameters:
        velocity (numpy.ndarray): Array of velocity values (in km/s).
        v_separation (float): Velocity separation between the two Gaussians (in km/s).
        asymmetry (float): Ratio of the red Gaussian's amplitude to the total amplitude.
        sigma_alpha (float): Velocity dispersion for both Gaussians (in km/s).

    Returns:
        numpy.ndarray: Combined Lyα line shape values.
    """
    # Calculate amplitudes of the red and blue Gaussians
    L_red = asymmetry
    L_blue = 1 - asymmetry

    # Define velocity offsets for the two Gaussians
    delta_v_red = v_separation / 2
    delta_v_blue = -v_separation / 2

    # Calculate the two Gaussian profiles
    red_gaussian = L_red * intrinsic_lya_lineshape(velocity, delta_v_red, sigma_alpha)
    blue_gaussian = L_blue * intrinsic_lya_lineshape(velocity, delta_v_blue, sigma_alpha)

    # Combine the two Gaussians
    combined_lineshape = red_gaussian + blue_gaussian
    return combined_lineshape

# Example usage
if __name__ == "__main__":
    # Define parameters
    sigma_alpha = 50  # Velocity dispersion (km/s)

    # Generate velocity array (km/s)
    velocity = np.linspace(-500, 500, 1000)

    # Example configurations for v_separation and asymmetry
    configurations = [
        (200, 0.5),  # Equal contribution from red and blue
        (300, 0.7),  # Red dominates
        (100, 0.3),  # Blue dominates
    ]

    # Plot examples
    plt.figure(figsize=(10, 8))
    for v_separation, asymmetry in configurations:
        lineshape = double_gaussian_lya_lineshape(velocity, v_separation, asymmetry, sigma_alpha)
        plt.plot(velocity, lineshape, label=f"v_sep={v_separation} km/s, asym={asymmetry}")

    plt.title("Double Gaussian Lyα Line Shape Examples")
    plt.xlabel("Velocity (km/s)")
    plt.ylabel("Intensity")
    plt.legend()
    plt.grid()
    plt.show()
